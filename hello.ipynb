# %%
from manim import *

class Hello(Scene):
    def construct(self):
        text = Text("Hello Tutoria")
        self.play(Write(text))
        self.wait()

# %%
# !manim -qm hello.py Hello
# Out:
# Manim Community v0.20.1
#
# [04/13/26 06:23:37] ERROR                                       ]8;id=9216929;file:///srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/module_ops.py\module_ops.py]8;;\:]8;id=9216930;file:///srv/conda/envs/notebook/lib/python3.11/site-packages/manim/utils/module_ops.py#91\91]8;;\
#                                 There are no scenes inside that
#                              module
